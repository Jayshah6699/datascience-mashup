# %% [markdown]
# ##**MODULE 6 :CLUSTERING FOR DIVERSIFICATION ANALYSIS**
#
# *Clustering is a Machine Learning technique that involves the grouping of data points. Given a set of data points, we can use a clustering algorithm to classify each data point into a specific group. In theory, data points that are in the same group should have similar properties and/or features, while data points in different groups should have highly dissimilar properties and/or features.*
#
# *In financial Markets, Cluster analysis is a technique used to group sets of objects that share similar characteristics. It is common in statistics, but investors will use the approach to build a diversified portfolio. Stocks that exhibit high correlations in returns fall into one basket, those slightly less correlated in another, and so on, until each stock is placed into a category.*

# %% [markdown]
# ###***6.1***
# *Create a table/data frame with the closing prices of 30 different stocks, with 10 from each of the caps*

# %% [markdown]
# **THE LARGE CAP STOCKS SELECTED ARE :**
# *   HUL
# *   ITC
# *   ADANIPORTS
# *   ASIANPAINT
# *   AXISBANK
# *   MARUTI
# *   RELIANCE
# *   SUNPHARMA
# *   TCS
# *   TITAN

# %%
# Import pandas and numpy library
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/content/HUL.csv')
df1.head(5)
# Out:
#        Symbol Series         Date  ...  14 Day STD  Upper Band  Lower Band
# 0  HINDUNILVR     EQ  15-May-2017  ...         NaN         NaN         NaN
# 1  HINDUNILVR     EQ  16-May-2017  ...         NaN         NaN         NaN
# 2  HINDUNILVR     EQ  17-May-2017  ...         NaN         NaN         NaN
# 3  HINDUNILVR     EQ  18-May-2017  ...         NaN         NaN         NaN
# 4  HINDUNILVR     EQ  19-May-2017  ...         NaN         NaN         NaN
#
# [5 rows x 23 columns]

# %%
df2 = pd.read_csv('/content/ITC.csv')
df2.head(5)
# Out:
#   Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0    ITC     EQ  ...         4128324                   75.57
# 1    ITC     EQ  ...         8307567                   74.15
# 2    ITC     EQ  ...         5924804                   71.40
# 3    ITC     EQ  ...         5434449                   68.58
# 4    ITC     EQ  ...        19137631                   53.57
#
# [5 rows x 15 columns]

# %%
df3 = pd.read_csv('/content/ADANIPORTS.csv')
df3.head(5)
# Out:
#        Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  ADANIPORTS     EQ  ...          554124                   36.20
# 1  ADANIPORTS     EQ  ...          465010                   35.19
# 2  ADANIPORTS     EQ  ...          571621                   46.10
# 3  ADANIPORTS     EQ  ...          963959                   26.64
# 4  ADANIPORTS     EQ  ...          492222                   37.78
#
# [5 rows x 15 columns]

# %%
df4 = pd.read_csv('/content/ASIANPAINT.csv')
df4.head(5)
# Out:
#        Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  ASIANPAINT     EQ  ...          471377                   64.62
# 1  ASIANPAINT     EQ  ...          641893                   70.26
# 2  ASIANPAINT     EQ  ...          282528                   48.74
# 3  ASIANPAINT     EQ  ...          436095                   62.12
# 4  ASIANPAINT     EQ  ...         1021656                   58.96
#
# [5 rows x 15 columns]

# %%
df5 = pd.read_csv('/content/AXISBANK.csv')
df5.head(5)
# Out:
#      Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  AXISBANK     EQ  ...         4320438                   49.06
# 1  AXISBANK     EQ  ...         4027982                   46.78
# 2  AXISBANK     EQ  ...         2876528                   44.64
# 3  AXISBANK     EQ  ...         5348691                   57.97
# 4  AXISBANK     EQ  ...         4190505                   55.06
#
# [5 rows x 15 columns]

# %%
df6 = pd.read_csv('/content/MARUTI.csv')
df6.head(5)
# Out:
#    Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  MARUTI     EQ  ...          154743                   46.01
# 1  MARUTI     EQ  ...          360641                   50.97
# 2  MARUTI     EQ  ...          260033                   58.37
# 3  MARUTI     EQ  ...          188907                   46.44
# 4  MARUTI     EQ  ...          234662                   42.49
#
# [5 rows x 15 columns]

# %%
df7 = pd.read_csv('/content/RELIANCE.csv')
df7.head(5)
# Out:
#      Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  RELIANCE     EQ  ...          802733                   52.12
# 1  RELIANCE     EQ  ...         1238129                   42.80
# 2  RELIANCE     EQ  ...         1225837                   54.47
# 3  RELIANCE     EQ  ...         1339478                   59.85
# 4  RELIANCE     EQ  ...         1444387                   49.32
#
# [5 rows x 15 columns]

# %%
df8 = pd.read_csv('/content/SUNPHARMA.csv')
df8.head(5)
# Out:
#       Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  SUNPHARMA     EQ  ...          846103                   69.13
# 1  SUNPHARMA     EQ  ...         1790950                   77.03
# 2  SUNPHARMA     EQ  ...         1418894                   73.88
# 3  SUNPHARMA     EQ  ...         1504397                   69.99
# 4  SUNPHARMA     EQ  ...         1471827                   66.20
#
# [5 rows x 15 columns]

# %%
df9 = pd.read_csv('/content/TCS.csv')
df9.head(5)
# Out:
#   Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0    TCS     EQ  ...          712450                   78.39
# 1    TCS     EQ  ...         1167534                   64.84
# 2    TCS     EQ  ...         1031752                   71.74
# 3    TCS     EQ  ...         1135613                   44.20
# 4    TCS     EQ  ...          517461                   57.94
#
# [5 rows x 15 columns]

# %%
df10 = pd.read_csv('/content/TITAN.csv')
df10.head(5)
# Out:
#   Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  TITAN     EQ  ...         1722661                   44.20
# 1  TITAN     EQ  ...          563667                   43.07
# 2  TITAN     EQ  ...          448314                   52.19
# 3  TITAN     EQ  ...          438716                   54.08
# 4  TITAN     EQ  ...          263561                   25.78
#
# [5 rows x 15 columns]

# %% [markdown]
# **THE MID CAP STOCKS SELECTED ARE :**
# *   JUBLFOOD
# *   GODREJIND
# *   APOLLOTYRES
# *   BERGEPAINT
# *   CASTROLIND
# *   CUMMINSIND
# *   IDBI
# *   PNB
# *   TATACHEM
# *   TATAPOWER

# %%
df11 = pd.read_csv('/content/JUBLFOOD.csv')
df11.head(5)
# Out:
#      Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  JUBLFOOD     EQ  ...          115368                   20.01
# 1  JUBLFOOD     EQ  ...           84859                   17.41
# 2  JUBLFOOD     EQ  ...           61936                   15.73
# 3  JUBLFOOD     EQ  ...           40599                   10.64
# 4  JUBLFOOD     EQ  ...           60049                   20.86
#
# [5 rows x 15 columns]

# %%
df12 = pd.read_csv('/content/GODREJIND.csv')
df12.head(5)
# Out:
#       Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  GODREJIND     EQ  ...          360927                   45.28
# 1  GODREJIND     EQ  ...          210364                   42.05
# 2  GODREJIND     EQ  ...          261667                   51.90
# 3  GODREJIND     EQ  ...           99785                   44.63
# 4  GODREJIND     EQ  ...           68041                   27.72
#
# [5 rows x 15 columns]

# %%
df13 = pd.read_csv('/content/APOLLOTYRE.csv')
df13.head(5)
# Out:
#        Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  APOLLOTYRE     EQ  ...         1801217                   41.43
# 1  APOLLOTYRE     EQ  ...         1570680                   45.84
# 2  APOLLOTYRE     EQ  ...         1845182                   35.35
# 3  APOLLOTYRE     EQ  ...         1615604                   40.74
# 4  APOLLOTYRE     EQ  ...         3057294                   57.00
#
# [5 rows x 15 columns]

# %%
df14 = pd.read_csv('/content/BERGEPAINT.csv')
df14.head(5)
# Out:
#        Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  BERGEPAINT     EQ  ...          351310                   50.68
# 1  BERGEPAINT     EQ  ...          243949                   53.55
# 2  BERGEPAINT     EQ  ...           95378                   29.30
# 3  BERGEPAINT     EQ  ...          137486                   38.04
# 4  BERGEPAINT     EQ  ...          150223                   31.36
#
# [5 rows x 15 columns]

# %%
df15 = pd.read_csv('/content/CASTROLIND.csv')
df15.head(5)
# Out:
#        Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  CASTROLIND     EQ  ...         1637034                   81.11
# 1  CASTROLIND     EQ  ...          387126                   72.38
# 2  CASTROLIND     EQ  ...          223768                   59.32
# 3  CASTROLIND     EQ  ...          211541                   53.06
# 4  CASTROLIND     EQ  ...          354918                   40.04
#
# [5 rows x 15 columns]

# %%
df16 = pd.read_csv('/content/CUMMINSIND.csv')
df16.head(5)
# Out:
#        Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  CUMMINSIND     EQ  ...           67829                   46.56
# 1  CUMMINSIND     EQ  ...          111884                   63.36
# 2  CUMMINSIND     EQ  ...          140100                   53.60
# 3  CUMMINSIND     EQ  ...          447682                   45.48
# 4  CUMMINSIND     EQ  ...          882502                   31.44
#
# [5 rows x 15 columns]

# %%
df17 = pd.read_csv('/content/IDBI.csv')
df17.head(5)
# Out:
#   Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0   IDBI     EQ  ...         1486475                   22.22
# 1   IDBI     EQ  ...         2578070                   29.50
# 2   IDBI     EQ  ...          643174                   20.40
# 3   IDBI     EQ  ...         2852529                   18.91
# 4   IDBI     EQ  ...         1949156                   17.77
#
# [5 rows x 15 columns]

# %%
df18 = pd.read_csv('/content/PNB.csv')
df18.head(5)
# Out:
#   Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0    PNB     EQ  ...         1352589                   18.09
# 1    PNB     EQ  ...         5804867                   11.26
# 2    PNB     EQ  ...         7037498                   26.52
# 3    PNB     EQ  ...         3245443                   23.34
# 4    PNB     EQ  ...         2816963                   17.27
#
# [5 rows x 15 columns]

# %%
df19 = pd.read_csv('/content/TATACHEM.csv')
df19.head(5)
# Out:
#      Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  TATACHEM     EQ  ...          137793                   39.51
# 1  TATACHEM     EQ  ...          221740                   51.94
# 2  TATACHEM     EQ  ...           79983                   26.25
# 3  TATACHEM     EQ  ...          224935                   47.77
# 4  TATACHEM     EQ  ...           67972                   23.84
#
# [5 rows x 15 columns]

# %%
df20 = pd.read_csv('/content/TATAPOWER.csv')
df20.head(5)
# Out:
#       Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  TATAPOWER     EQ  ...          796744                   39.68
# 1  TATAPOWER     EQ  ...         2125318                   41.34
# 2  TATAPOWER     EQ  ...         2264851                   41.18
# 3  TATAPOWER     EQ  ...         1217618                   53.02
# 4  TATAPOWER     EQ  ...         1918659                   30.83
#
# [5 rows x 15 columns]

# %% [markdown]
# **THE SMALL CAP STOCKS SELECTED ARE :**
# *   PVR
# *   VENKEYS
# *   CENTUARY PLY
# *   BAJAJELEC
# *   BOMDYEING
# *   JETAIRWAYS
# *   JKLAKSHMI
# *   LEMONTREE
# *   LUXIND
# *   RAYMOND

# %%
df21 = pd.read_csv('/content/PVR.csv')
df21.head(5)
# Out:
#   Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0    PVR     EQ  ...           54518                   52.58
# 1    PVR     EQ  ...           39020                   45.09
# 2    PVR     EQ  ...           21303                   28.83
# 3    PVR     EQ  ...           38796                   47.24
# 4    PVR     EQ  ...           54764                   47.67
#
# [5 rows x 15 columns]

# %%
df22 = pd.read_csv('/content/VENKEYS.csv')
df22.head(5)
# Out:
#     Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  VENKEYS     EQ  ...           40813                   40.95
# 1  VENKEYS     EQ  ...           22051                   35.81
# 2  VENKEYS     EQ  ...           17361                   28.57
# 3  VENKEYS     EQ  ...           12506                   43.68
# 4  VENKEYS     EQ  ...           11738                   41.16
#
# [5 rows x 15 columns]

# %%
df23 = pd.read_csv('/content/CENTURYPLY.csv')
df23.head(5)
# Out:
#        Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  CENTURYPLY     EQ  ...          116668                   56.52
# 1  CENTURYPLY     EQ  ...          136850                   61.82
# 2  CENTURYPLY     EQ  ...          377919                   88.04
# 3  CENTURYPLY     EQ  ...           24816                   33.89
# 4  CENTURYPLY     EQ  ...           50131                   47.30
#
# [5 rows x 15 columns]

# %%
df24 = pd.read_csv('/content/BAJAJELEC.csv')
df24.head(5)
# Out:
#       Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  BAJAJELEC     EQ  ...           91705                   61.03
# 1  BAJAJELEC     EQ  ...           53340                   44.88
# 2  BAJAJELEC     EQ  ...           46366                   42.70
# 3  BAJAJELEC     EQ  ...           91087                   57.41
# 4  BAJAJELEC     EQ  ...           47468                   36.73
#
# [5 rows x 15 columns]

# %%
df25 = pd.read_csv('/content/BOMDYEING.csv')
df25.head(5)
# Out:
#       Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  BOMDYEING     EQ  ...          479867                   30.89
# 1  BOMDYEING     EQ  ...          561852                   26.14
# 2  BOMDYEING     EQ  ...          395417                   31.20
# 3  BOMDYEING     EQ  ...          538431                   46.56
# 4  BOMDYEING     EQ  ...          518874                   35.92
#
# [5 rows x 15 columns]

# %%
df26 = pd.read_csv('/content/JETAIRWAYS.csv')
df26.head(5)
# Out:
#        Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  JETAIRWAYS     EQ  ...          430754                   23.45
# 1  JETAIRWAYS     EQ  ...          284837                   20.61
# 2  JETAIRWAYS     EQ  ...           53551                    7.76
# 3  JETAIRWAYS     EQ  ...          309608                   18.20
# 4  JETAIRWAYS     EQ  ...          257037                   20.19
#
# [5 rows x 15 columns]

# %%
df27 = pd.read_csv('/content/JKLAKSHMI.csv')
df17.head(5)
# Out:
#   Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0   IDBI     EQ  ...         1486475                   22.22
# 1   IDBI     EQ  ...         2578070                   29.50
# 2   IDBI     EQ  ...          643174                   20.40
# 3   IDBI     EQ  ...         2852529                   18.91
# 4   IDBI     EQ  ...         1949156                   17.77
#
# [5 rows x 15 columns]

# %%
df28 = pd.read_csv('/content/LEMONTREE.csv')
df28.head(5)
# Out:
#       Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  LEMONTREE     EQ  ...        13918070                   20.58
# 1  LEMONTREE     EQ  ...         3186294                   20.94
# 2  LEMONTREE     EQ  ...         2323539                   25.55
# 3  LEMONTREE     EQ  ...          681080                   28.28
# 4  LEMONTREE     EQ  ...          994028                   41.31
#
# [5 rows x 15 columns]

# %%
df29 = pd.read_csv('/content/LUXIND.csv')
df29.head(5)
# Out:
#    Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  LUXIND     EQ  ...            2498                   78.50
# 1  LUXIND     EQ  ...            6192                   86.47
# 2  LUXIND     EQ  ...            3914                   73.20
# 3  LUXIND     EQ  ...            4032                   71.29
# 4  LUXIND     EQ  ...            3856                   75.59
#
# [5 rows x 15 columns]

# %%
df30 = pd.read_csv('/content/RAYMOND.csv')
df30.head(5)
# Out:
#     Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0  RAYMOND     EQ  ...           55467                   18.96
# 1  RAYMOND     EQ  ...          179377                   21.77
# 2  RAYMOND     EQ  ...          127637                   21.34
# 3  RAYMOND     EQ  ...           92200                   28.83
# 4  RAYMOND     EQ  ...          137648                   24.52
#
# [5 rows x 15 columns]

# %%
df_new=pd.DataFrame()

df_new['HUL']=df1['Close Price']
df_new['ITC']=df2['Close Price']
df_new['ADANIPORTS']=df3['Close Price']
df_new['ASIANPAINT']=df4['Close Price']
df_new['AXISBANK']=df5['Close Price']
df_new['MARUTI']=df6['Close Price']
df_new['RELIANCE']=df7['Close Price']
df_new['SUNPHARMA']=df8['Close Price']
df_new['TCS']=df9['Close Price']
df_new['TITAN']=df10['Close Price']

df_new['JUBLFOOD']=df11['Close Price']
df_new['GODREJIND']=df12['Close Price']
df_new['APOLLOTYRES']=df13['Close Price']
df_new['BERGEPAINT']=df14['Close Price']
df_new['CASTROLIND']=df15['Close Price']
df_new['CUMMINSIND']=df16['Close Price']
df_new['IDBI']=df17['Close Price']
df_new['PNB']=df18['Close Price']
df_new['TATACHEM']=df19['Close Price']
df_new['TATAPOWER']=df20['Close Price']

df_new['PVR']=df21['Close Price']
df_new['VENKEYSL']=df22['Close Price']
df_new['CENTURYPLY']=df23['Close Price']
df_new['BAJAJELEC']=df24['Close Price']
df_new['BOMDYEING']=df25['Close Price']
df_new['JETAIRWAYS']=df26['Close Price']
df_new['JKLAKSHMI']=df27['Close Price']
df_new['LEMONTREE']=df28['Close Price']
df_new['LUXIND']=df29['Close Price']
df_new['RAYMOND']=df30['Close Price']

df_new.head(5)
# Out:
#        HUL     ITC  ADANIPORTS  ...  LEMONTREE  LUXIND  RAYMOND
# 0   983.25  277.95      356.20  ...      71.65  819.60   772.80
# 1  1000.40  283.45      354.50  ...      66.85  817.50   785.00
# 2  1009.40  281.65      348.55  ...      66.95  819.80   783.65
# 3   990.25  277.90      347.90  ...      66.40  820.05   746.95
# 4  1008.00  286.20      349.45  ...      67.70  817.80   723.10
#
# [5 rows x 30 columns]

# %%
df_new.tail(5)
# Out:
#          HUL     ITC  ADANIPORTS  ...  LEMONTREE   LUXIND  RAYMOND
# 489  1697.50  304.25      379.80  ...        NaN  1314.40   808.95
# 490  1688.70  307.00      371.90  ...        NaN  1268.50   807.10
# 491  1703.75  301.90      369.80  ...        NaN  1248.20   805.30
# 492  1687.45  300.65      363.90  ...        NaN  1239.95   804.40
# 493  1702.00  299.85      372.55  ...        NaN  1211.55   779.35
#
# [5 rows x 30 columns]

# %%
df_new.shape
# Out:
# (494, 30)

# %%
df_new.size
# Out:
# 14820

# %%
df_new.describe()
# Out:
#                HUL         ITC  ...       LUXIND      RAYMOND
# count   494.000000  494.000000  ...   494.000000   494.000000
# mean   1475.635020  281.602126  ...  1462.075607   857.047065
# std     240.389378   17.769478  ...   308.205534   119.766977
# min     983.250000  251.600000  ...   789.150000   600.450000
# 25%    1268.037500  267.662500  ...  1203.850000   774.575000
# 50%    1503.825000  277.675000  ...  1463.700000   817.300000
# 75%    1698.187500  293.587500  ...  1731.237500   946.125000
# max    1860.550000  342.500000  ...  2074.850000  1132.400000
#
# [8 rows x 30 columns]

# %% [markdown]
# ###***6.2***
# *Average annual percentage return and volatility of all 30 stocks over a theoretical one year period*

# %%
df_new=df_new.pct_change()
df_new.fillna(0,inplace=True)
df_new.head(10)
# Out:
#         HUL       ITC  ADANIPORTS  ...  LEMONTREE    LUXIND   RAYMOND
# 0  0.000000  0.000000    0.000000  ...   0.000000  0.000000  0.000000
# 1  0.017442  0.019788   -0.004773  ...  -0.066992 -0.002562  0.015787
# 2  0.008996 -0.006350   -0.016784  ...   0.001496  0.002813 -0.001720
# 3 -0.018972 -0.013314   -0.001865  ...  -0.008215  0.000305 -0.046832
# 4  0.017925  0.029867    0.004455  ...   0.019578 -0.002744 -0.031930
# 5  0.010516  0.060797    0.014308  ...  -0.006647 -0.000917 -0.009888
# 6  0.006087 -0.011364   -0.064325  ...   0.018587 -0.011933 -0.022907
# 7  0.012929 -0.000833    0.024122  ...  -0.006569 -0.018952 -0.053320
# 8  0.005202  0.000500    0.003239  ...   0.055841  0.019318  0.024236
# 9 -0.002396  0.030162    0.021277  ...   0.164927  0.005141  0.063173
#
# [10 rows x 30 columns]

# %%
#average annual percentage return
returns = df_new.mean() * 252
returns
#Concatenating the returns and variances into a single data-frame
# Out:
# HUL            0.298772
# ITC            0.063885
# ADANIPORTS     0.071056
# ASIANPAINT     0.101044
# AXISBANK       0.234770
# MARUTI         0.010174
# RELIANCE       0.094928
# SUNPHARMA     -0.146316
# TCS            0.080307
# TITAN          0.472152
# JUBLFOOD       0.266973
# GODREJIND     -0.090067
# APOLLOTYRES   -0.064172
# BERGEPAINT     0.108714
# CASTROLIND    -0.433678
# CUMMINSIND    -0.177269
# IDBI          -0.295409
# PNB           -0.238955
# TATACHEM       0.002186
# TATAPOWER     -0.090766
# PVR            0.108310
# VENKEYSL       0.380938
# CENTURYPLY    -0.181969
# BAJAJELEC      0.315413
# BOMDYEING      0.326958
# JETAIRWAYS    -0.480045
# JKLAKSHMI     -0.168523
# LEMONTREE      0.030927
# LUXIND         0.254644
# RAYMOND        0.069879
# dtype: float64

# %%
#volatility
variance = df_new.std() * (252**(0.5))
variance
# Out:
# HUL            0.193846
# ITC            0.223636
# ADANIPORTS     0.309065
# ASIANPAINT     0.209194
# AXISBANK       0.277614
# MARUTI         0.225029
# RELIANCE       0.438645
# SUNPHARMA      0.342079
# TCS            0.430949
# TITAN          0.324035
# JUBLFOOD       0.500496
# GODREJIND      0.266380
# APOLLOTYRES    0.310130
# BERGEPAINT     0.267396
# CASTROLIND     0.446015
# CUMMINSIND     0.296244
# IDBI           0.453328
# PNB            0.544837
# TATACHEM       0.246608
# TATAPOWER      0.307984
# PVR            0.309876
# VENKEYSL       0.626748
# CENTURYPLY     0.374888
# BAJAJELEC      0.402006
# BOMDYEING      0.602258
# JETAIRWAYS     0.624221
# JKLAKSHMI      0.279385
# LEMONTREE      0.289258
# LUXIND         0.335070
# RAYMOND        0.363465
# dtype: float64

# %% [markdown]
# ###***6.3***
# *Cluster the 30 stocks according to their mean annual Volatilities and Returns using K-means clustering. Identify the optimum number of clusters using the Elbow curve method*

# %%
ret_var=pd.DataFrame()
ret_var['returns']=returns
ret_var['variance']=variance
ret_var
# Out:
#               returns  variance
# HUL          0.298772  0.193846
# ITC          0.063885  0.223636
# ADANIPORTS   0.071056  0.309065
# ASIANPAINT   0.101044  0.209194
# AXISBANK     0.234770  0.277614
# MARUTI       0.010174  0.225029
# RELIANCE     0.094928  0.438645
# SUNPHARMA   -0.146316  0.342079
# TCS          0.080307  0.430949
# TITAN        0.472152  0.324035
# JUBLFOOD     0.266973  0.500496
# GODREJIND   -0.090067  0.266380
# APOLLOTYRES -0.064172  0.310130
# BERGEPAINT   0.108714  0.267396
# CASTROLIND  -0.433678  0.446015
# CUMMINSIND  -0.177269  0.296244
# IDBI        -0.295409  0.453328
# PNB         -0.238955  0.544837
# TATACHEM     0.002186  0.246608
# TATAPOWER   -0.090766  0.307984
# PVR          0.108310  0.309876
# VENKEYSL     0.380938  0.626748
# CENTURYPLY  -0.181969  0.374888
# BAJAJELEC    0.315413  0.402006
# BOMDYEING    0.326958  0.602258
# JETAIRWAYS  -0.480045  0.624221
# JKLAKSHMI   -0.168523  0.279385
# LEMONTREE    0.030927  0.289258
# ...

# %%
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
#Identify the optimum number of clusters using the Elbow curve method

X =  ret_var.values #Converting ret_var into nummpy array
list1 = []
fig = plt.figure(figsize=(15, 5))
for k in range(2,20):
    
    kmeans = KMeans(n_clusters = k)
    kmeans.fit(X)
    
    list1.append(kmeans.inertia_) #SSE for each n_clusters
plt.plot(range(2,20), list1)
plt.title("Elbow Curve")
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters = 5).fit(X)
centroids = kmeans.cluster_centers_
plt.title('K-Means Clustering on Stock Market Movements')
plt.scatter(X[:,0],X[:,1], c = kmeans.labels_, cmap ="gist_rainbow")
plt.grid(True)
plt.show()

# %% [markdown]
# ###***6.4***
# *A separate Data frame to show which stocks belong to the same cluster*

# %%
df_ans=pd.DataFrame()
df_ans['Company name']=ret_var.index
df_ans['Label name']=kmeans.labels_
df_ans
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/displayhook.py:260: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   'Flushing oldest {cull_count} entries.'.format(sz=sz, cull_count=cull_count))
#    Company name  Label name
# 0           HUL           4
# 1           ITC           3
# 2    ADANIPORTS           3
# 3    ASIANPAINT           3
# 4      AXISBANK           4
# 5        MARUTI           3
# 6      RELIANCE           3
# 7     SUNPHARMA           1
# 8           TCS           3
# 9         TITAN           4
# 10     JUBLFOOD           0
# 11    GODREJIND           1
# 12  APOLLOTYRES           1
# 13   BERGEPAINT           3
# 14   CASTROLIND           2
# 15   CUMMINSIND           1
# 16         IDBI           2
# 17          PNB           2
# 18     TATACHEM           3
# 19    TATAPOWER           1
# 20          PVR           3
# 21     VENKEYSL           0
# 22   CENTURYPLY           1
# 23    BAJAJELEC           4
# ...
